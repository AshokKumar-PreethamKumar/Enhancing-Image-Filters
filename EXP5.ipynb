# %%
# Ex. No: 05
## Implementation-of-filter-main
# Name : ASHOK KUMAR PREETHAM KUMAR
# Reg. No : 212224040032
# Slot No : T2-J6

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('lion.jpg')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
averaging = cv2.blur(img_rgb, (5, 5))

# %%
# Weighted Averaging Filter
kernel = np.array([[1, 2, 1],
                   [2, 4, 2],
                   [1, 2, 1]], np.float32) / 16

weighted_avg = cv2.filter2D(img_rgb, -1, kernel)

# %%
# Gaussian Filter
gaussian = cv2.GaussianBlur(img_rgb, (5, 5), 0)

# %%
# Median Filter
median = cv2.medianBlur(img_rgb, 5)

# %%
# Laplacian Sharpening using Kernel
sharpen_kernel = np.array([[0, -1, 0],
                           [-1, 5, -1],
                           [0, -1, 0]])

sharpened = cv2.filter2D(img_rgb, -1, sharpen_kernel)

# %%
# Laplacian Operator
gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)

laplacian = cv2.Laplacian(gray, cv2.CV_64F)
laplacian = np.uint8(np.absolute(laplacian))

# %%
titles = [
    'Original Image',
    'Averaging Filter',
    'Weighted Averaging',
    'Gaussian Filter',
    'Median Filter',
    'Laplacian Sharpening',
    'Laplacian Operator'
]

images = [
    img_rgb,
    averaging,
    weighted_avg,
    gaussian,
    median,
    sharpened,
    laplacian
]

# %%
plt.figure(figsize=(15, 10))

for i in range(len(images)):

    plt.subplot(3, 3, i + 1)

    if i == 6:
        plt.imshow(images[i], cmap='gray')
    else:
        plt.imshow(images[i])

    plt.title(titles[i])
    plt.axis('off')

plt.tight_layout()
plt.show()
